# %% [markdown]
# <a href="https://colab.research.google.com/github/osamasarhan/AI-Ignition-system/blob/master/kagglex_pycaret_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# From source
# !pip install git+https://github.com/pycaret/pycaret.git#egg=pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/pycaret/pycaret.git to /tmp/pip-install-oi2t5mcr/pycaret_36c64402e3fc4583b3b5e9072f623bdd
#   Running command git clone --filter=blob:none --quiet https://github.com/pycaret/pycaret.git /tmp/pip-install-oi2t5mcr/pycaret_36c64402e3fc4583b3b5e9072f623bdd
#   Resolved https://github.com/pycaret/pycaret.git to commit dae503768ba447c6171f327b5c9f800ee86724b7
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 KB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 48.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 9.0 MB/s eta 0:00:00
# ...

# %%
# !pip install numpy>=1.21

# %% [markdown]
# # List of Datasets

# %%
from pycaret.datasets import get_data
all_datasets = get_data('index')
all_datasets
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# # Classification
#
# https://pycaret.gitbook.io/docs/get-started/quickstart#classification

# %%
from pycaret.classification import * 
# Select one dataset
employee = get_data('employee', profile=True)
employee
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-13 20:05:08.296909&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# Pre-processing: https://pycaret.gitbook.io/docs/get-started/preprocessing

# %%
emp_clf = setup(employee, target = 'left',
                session_id=123, 
               )
# Out:
# <style type="text/css">
# #T_a7664_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a7664" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7664_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a7664_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7664_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7664_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a7664_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a7664_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7664_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a7664_row1_col1" class="data row1 col1" >left</td>
#     </tr>
#     <tr>
#       <th id="T_a7664_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# test_ro = setup(data = employee, target = 'left', remove_outliers = True)
# Out:
# <style type="text/css">
# #T_1a1c1_row9_col1, #T_1a1c1_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a1c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a1c1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1a1c1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a1c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a1c1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1a1c1_row0_col1" class="data row0 col1" >4275</td>
#     </tr>
#     <tr>
#       <th id="T_1a1c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a1c1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1a1c1_row1_col1" class="data row1 col1" >left</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Compare models and get the best models

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a5d94 th {
#   text-align: left;
# }
# ...

# %%
# Model with parameters
best
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %%
dt = create_model('dt')
dt
# Out:
# <style type="text/css">
# #T_bf680_row10_col0, #T_bf680_row10_col1, #T_bf680_row10_col2, #T_bf680_row10_col3, #T_bf680_row10_col4, #T_bf680_row10_col5, #T_bf680_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bf680" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf680_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bf680_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bf680_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bf680_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bf680_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bf680_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bf680_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# # Analysis of model

# %%
plot_model(dt, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'confusion_matrix', plot_kwargs = {'percent' : True})

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(dt, plot = 'feature')

# %%
plot_model(best, plot = 'feature')

# %% [markdown]
# ## Tune the hyperparameters of the model. The output of this function is a scoring grid with cross-validated scores by fold.

# %%
tuned_dt = tune_model(dt)
tuned_dt
# Out:
# <style type="text/css">
# #T_dc45e_row10_col0, #T_dc45e_row10_col1, #T_dc45e_row10_col2, #T_dc45e_row10_col3, #T_dc45e_row10_col4, #T_dc45e_row10_col5, #T_dc45e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_dc45e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc45e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dc45e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dc45e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dc45e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dc45e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dc45e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dc45e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_best = tune_model(best)
tuned_best
# Out:
# <style type="text/css">
# #T_60256_row10_col0, #T_60256_row10_col1, #T_60256_row10_col2, #T_60256_row10_col3, #T_60256_row10_col4, #T_60256_row10_col5, #T_60256_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_60256" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60256_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_60256_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_60256_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_60256_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_60256_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_60256_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_60256_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# ## Prediction

# %%
# predict on new data
emp1 = get_data('employee')
new_data = employee.copy()
new_data.drop('left', axis = 1, inplace = True)
predict_model(best, data=new_data)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years department  \
# 0                   3              0                      0      sales
# 1                   6              0                      0      sales
# 2                   4              0                      0      sales
# 3                   5              0                      0      sales
# 4                   3              0                      0      sales
#
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# ...

# %%
best
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %% [markdown]
# # Save and Deploy model
#
# https://pycaret.gitbook.io/docs/get-started/functions/deploy

# %%
finalize_model(best)
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['satisfaction_level',
#                                              'last_evaluation',
#                                              'number_project',
#                                              'average_montly_hours',
#                                              'time_spend_company',
#                                              'Work_accident',
#                                              'promotion_last_5years'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features...
# ...

# %%
save_model(best, 'demo_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['satisfaction_level',
#                                               'last_evaluation',
#                                               'number_project',
#                                               'average_montly_hours',
#                                               'time_spend_company',
#                                               'Work_accident',
#                                               'promotion_last_5years'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
# ...

# %%
# To load the model back in the environment

loaded_model = load_model('/content/demo_pipeline')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['satisfaction_level',
#                                              'last_evaluation',
#                                              'number_project',
#                                              'average_montly_hours',
#                                              'time_spend_company',
#                                              'Work_accident',
#                                              'promotion_last_5years'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
# ...
